# %%
import numpy as np
import pandas as pd
import seaborn as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sympy import  symbols,diff
import warnings
warnings.filterwarnings('ignore')
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x,y):
    r=3**(-x**2-y**2)
    return 1/(r+1)
x_1=np.linspace(-2,2,300)
y_1=np.linspace(-2,2,300)
x_1,y_1=np.meshgrid(x_1,y_1)
a,b=symbols("x,y")

# %%
fig=plt.figure(figsize=[16,12])
ax=ax=fig.gca(projection='3d')
ax.plot_surface(x_1,y_1,f(x_1,y_1),cmap=cm.coolwarm)
plt.show()

# %%
diff(f(a,b),a)
# Out:
# 2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2

# %%
diff(f(a,b),b)
# Out:
# 2*3**(-x**2 - y**2)*y*log(3)/(3**(-x**2 - y**2) + 1)**2

# %%
def dfx(x,y):
    a=3**((-x**2)-(y**2))
    r1=2*a*(x*np.log(3))
    r2=(a+1)**2
    return r1/r2
def dfy(x,y):
    a=3**((-x**2)-(y**2))
    r1=2*a*(y*np.log(3))
    r2=(a+1)**2
    return r1/r2
def gradient_decent(params,dfx,dfy,gamma):
    gradient_x=dfx()

# %%
def gradient_decent(intial_params,gamma,driFuncX,driFuncY,max_iter=300):
    gradient_x_slop=[]
    gradient_y_slop=[]
    for i in range(max_iter):
        params=np.array(intial_params)
        value_param=params.reshape(1,2)
        gradient_x=driFuncX(params[0],params[1])
        gradient_y=driFuncY(params[0],params[1])
        gradient=np.array([gradient_x,gradient_y])
        params=params-gamma*gradient
        gradient_x_slop.append(gradient_x)
        gradient_y_slop.append(gradient_y)
        value_param=np.append(arr=value_param,values=params.reshape(1,2),axis=0)
    return value_param
    
grad,values_par=gradient_decent([1.8,1.0],0.5,dfx,dfy)
