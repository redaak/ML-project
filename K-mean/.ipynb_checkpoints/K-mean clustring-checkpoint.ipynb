# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans,kmeans_plusplus
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import yfinance as yt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=pd.read_csv('Mall_Customers.csv')
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
lb=LabelEncoder()
dataset.Genre=lb.fit_transform(dataset.Genre)

# %%
dataset
# Out:
#      CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1      1   19                  15                      39
# 1             2      1   21                  15                      81
# 2             3      0   20                  16                       6
# 3             4      0   23                  16                      77
# 4             5      0   31                  17                      40
# ..          ...    ...  ...                 ...                     ...
# 195         196      0   35                 120                      79
# 196         197      0   45                 126                      28
# 197         198      1   32                 126                      74
# 198         199      1   32                 137                      18
# 199         200      1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
sns.pairplot(dataset,hue="Genre",corner=True)

# %%
frequ=dataset.Genre.value_counts()

# %%
plt.figure(figsize=(6,6))
plt.pie(frequ,labels=["female","male"],
       textprops={'fontsize':18},
        autopct='%1.1f%%',
        startangle=90,explode=[0,0.1])
plt.show()

# %%
plt.figure(figsize=(6,6))
custom_color=['#33d9b2','#ff5252']
plt.pie(frequ,labels=["female","male"],
        textprops={'fontsize':17},
        autopct='%1.1f%%',
        startangle=90,
        pctdistance=0.8)

center_circle=plt.Circle((0,0),radius=0.6,fc='white')
plt.gca().add_artist(center_circle)
plt.title("pie chart")
plt.show()

# %%
dataset.head()
# Out:
#    CustomerID  Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1      1   19                  15                      39
# 1           2      1   21                  15                      81
# 2           3      0   20                  16                       6
# 3           4      0   23                  16                      77
# 4           5      0   31                  17                      40

# %%
df=pd.DataFrame(yt.Ticker("KO").history())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df=pd.DataFrame(yt.Ticker("KO"))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
df
# Out:
# yfinance.Ticker object <KO>
