# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading data and saperate features from target

# %%
dataset=pd.read_csv('Salary_Data.csv')
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
print(dataset)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# # Visualize data

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(8,5))
plt.plot(x,y)
plt.xlabel('years of experince')
plt.ylabel('Salary')
plt.title("Salary growth by the years of experince")
plt.show()

# %% [markdown]
# ## Spliting data to test and train

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # fitting the regression line

# %%
regr=LinearRegression()
regr.fit(x_train,y_train)
regr.score(x_test,y_test)
# Out:
# 0.9562342655332863

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(8,5))
plt.scatter(x,y)
plt.plot(x_test,regr.predict(x_test),c='red',alpha=0.6)
plt.xlabel('years of experince')
plt.ylabel('Salary')
plt.title("Salary growth by the years of experince")
plt.show()

# %%
regr.coef_
# Out:
# array([9358.35743396])

# %%
regr.intercept_
# Out:
# 25588.31712828877

# %%
def f(x):
    return regr.intercept_+(regr.coef_[0]*x)

# %%
f(12)
# Out:
# 137888.6063358642
